# %% [markdown]
# <img src="https://i.ibb.co/1MPXBQZ/ringodata-banner-v2.jpg" width="200"/>
#
#
# ---
# -  강의 및 추가 자료 링크
# - 강의 링크: [Python 강의](#)
#
# -  소셜 미디어 및 연락처
#   - 저자 SNS: [instagram](https://www.instagram.com/ringo_data/?igsh=MTlrdW4xMzZvNTBtdw%3D%3D), [LinkedIn](https://www.linkedin.com/in/ringokwon/)
#   - 이메일: ringo.data1@gmail.com
#
# ---

# %% [markdown]
# # px.bar()
# - `범주별 데이터 양이나 빈도 나타낼 때 사용. 예를 들어, 다른 제품 판매량 비교`
#
# ```python
# import plotly.express as px
#
# # 막대 그래프 생성
# fig = px.bar(df
#     , x="col_1"  # x축 데이터
#     , y="col_2"  # y축 데이터
#     , color="col_3"  # 막대 색상 구분, 'col_3' 값에 따라 달라짐
#     , title="title_name"  # 그래프 제목 설정
#     , barmode='group'  # 막대 표시 방식, 'group'은 나란히, 'stack'은 쌓아서 표시
# )
#
# # X축과 Y축 제목 설정 (선택적)
# # fig.update_layout(xaxis_title="x_title_name", yaxis_title="y_title_name")
#
# # 그래프 화면에 표시
# fig.show()
#
# ```

# %%
# 예시 데이터 생성
import pandas as pd

data = {
    'Month': ['January', 'February', 'March', 'January', 'February', 'March', 'January', 'February', 'March'],
    'Sales': [20000, 24000, 30000, 15000, 16000, 22000, 180000, 26000, 27000],
    'Ratio': [.234, .324, .3, .232, .1216, .332, .330, .330, .27],
    'Region': ['North', 'North', 'North', 'South', 'South', 'South', 'East', 'East', 'East']
}

df1 = pd.DataFrame(data)
df1
# Out:
#       Month   Sales   Ratio Region
# 0   January   20000  0.2340  North
# 1  February   24000  0.3240  North
# 2     March   30000  0.3000  North
# 3   January   15000  0.2320  South
# 4  February   16000  0.1216  South
# 5     March   22000  0.3320  South
# 6   January  180000  0.3300   East
# 7  February   26000  0.3300   East
# 8     March   27000  0.2700   East

# %%
import plotly.express as px

# 막대 그래프 생성
fig = px.bar(df1
    , x="Sales"  # x축 데이터
    , y="Month"  # y축 데이터
    #, color="col_3"  # 막대 색상 구분, 'col_3' 값에 따라 달라짐
    , title="Sales by Month"  # 그래프 제목 설정
    , barmode='group'  # 막대 표시 방식, 'group'은 나란히, 'stack'은 쌓아서 표시
)

# X축과 Y축 제목 설정 (선택적)
# fig.update_layout(xaxis_title="x_title_name", yaxis_title="y_title_name")

# 그래프 화면에 표시
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="3e73f39e-52ee-4237-845f-1ed8812f5f26" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3e73f39e-52ee-4237-845f-1ed8812f5f26")) {                    Plotly.newPlot(                        "3e73f39e-52ee-4237-845f-1ed8812f5f26",                        [{"alignmentgroup":"True","hovertemplate":"Sales=%{x}\u003cbr\u003eMonth=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","x":[20000,24000,30000,15000,16000,22000,180000,26000,27000],"xaxis":"x","y":["January","February","March","January","February","March","January","February","March"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type" ...

# %%
df1.head()
# Out:
#       Month  Sales   Ratio Region
# 0   January  20000  0.2340  North
# 1  February  24000  0.3240  North
# 2     March  30000  0.3000  North
# 3   January  15000  0.2320  South
# 4  February  16000  0.1216  South

# %%
df1_agg = df1.groupby( by = 'Month')['Sales'].sum().reset_index()

# %%
import plotly.express as px

# 막대 그래프 생성
fig = px.bar(df1
    , x="Sales"  # x축 데이터
    , y="Month"  # y축 데이터
    #, color="col_3"  # 막대 색상 구분, 'col_3' 값에 따라 달라짐
    , title="Sales by Month"  # 그래프 제목 설정
    , barmode='group'  # 막대 표시 방식, 'group'은 나란히, 'stack'은 쌓아서 표시
)

# X축과 Y축 제목 설정 (선택적)
# fig.update_layout(xaxis_title="x_title_name", yaxis_title="y_title_name")

# 그래프 화면에 표시
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="52b12bc9-fb45-46b4-9e0d-9505bc81248a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("52b12bc9-fb45-46b4-9e0d-9505bc81248a")) {                    Plotly.newPlot(                        "52b12bc9-fb45-46b4-9e0d-9505bc81248a",                        [{"alignmentgroup":"True","hovertemplate":"Sales=%{x}\u003cbr\u003eMonth=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","x":[20000,24000,30000,15000,16000,22000,180000,26000,27000],"xaxis":"x","y":["January","February","March","January","February","March","January","February","March"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type" ...

# %%
import plotly.express as px

# 막대 그래프 생성
fig = px.bar(df1
    , x="Sales"  # x축 데이터
    , y="Month"  # y축 데이터
    , color="Region"  # 막대 색상 구분, 'col_3' 값에 따라 달라짐
    , title="Sales by Month"  # 그래프 제목 설정
    , barmode='group'  # 막대 표시 방식, 'group'은 나란히, 'stack'은 쌓아서 표시
)

# X축과 Y축 제목 설정 (선택적)
# fig.update_layout(xaxis_title="x_title_name", yaxis_title="y_title_name")

# 그래프 화면에 표시
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="45abdff1-0f19-4b1a-a4a7-8e00096f78ed" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("45abdff1-0f19-4b1a-a4a7-8e00096f78ed")) {                    Plotly.newPlot(                        "45abdff1-0f19-4b1a-a4a7-8e00096f78ed",                        [{"alignmentgroup":"True","hovertemplate":"Region=North\u003cbr\u003eSales=%{x}\u003cbr\u003eMonth=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"North","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"North","offsetgroup":"North","orientation":"h","showlegend":true,"textposition":"auto","x":[20000,24000,30000],"xaxis":"x","y":["January","February","March"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=South\u003cbr\u003eSales=%{x}\u003cbr\u003eMonth=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"South","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"South","offsetgroup":"South","orientation":"h","showlegend":true,"textposition":"auto","x":[15000,16000,22000],"xaxis":"x","y":["January","February","March"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=East\u003cbr\u003eSales=%{x}\u003cbr\u003eMonth=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"East","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"East","offsetgroup":"East","orientation":"h","showlegend":true,"textposition":"auto","x":[180000,26000,27000],"xaxis":"x","y":["January","February","March"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[ ...

# %%
import plotly.express as px

# 막대 그래프 생성
fig = px.bar(df1
    , x="Sales"  # x축 데이터
    , y="Month"  # y축 데이터
    , color="Region"  # 막대 색상 구분, 'col_3' 값에 따라 달라짐
    , title="Sales by Month"  # 그래프 제목 설정
    , barmode='group'  # 막대 표시 방식, 'group'은 나란히, 'stack'은 쌓아서 표시
)

# X축과 Y축 제목 설정 (선택적)
fig.update_layout(xaxis_title="매출", yaxis_title="월")

# 그래프 화면에 표시
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="65a91221-e47e-41d1-be3d-ca3c0f369db7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("65a91221-e47e-41d1-be3d-ca3c0f369db7")) {                    Plotly.newPlot(                        "65a91221-e47e-41d1-be3d-ca3c0f369db7",                        [{"alignmentgroup":"True","hovertemplate":"Region=North\u003cbr\u003eSales=%{x}\u003cbr\u003eMonth=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"North","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"North","offsetgroup":"North","orientation":"h","showlegend":true,"textposition":"auto","x":[20000,24000,30000],"xaxis":"x","y":["January","February","March"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=South\u003cbr\u003eSales=%{x}\u003cbr\u003eMonth=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"South","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"South","offsetgroup":"South","orientation":"h","showlegend":true,"textposition":"auto","x":[15000,16000,22000],"xaxis":"x","y":["January","February","March"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=East\u003cbr\u003eSales=%{x}\u003cbr\u003eMonth=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"East","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"East","offsetgroup":"East","orientation":"h","showlegend":true,"textposition":"auto","x":[180000,26000,27000],"xaxis":"x","y":["January","February","March"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[ ...

# %% [markdown]
# # hover_data()
# ```python
# hover_data = {
#     'col_1': True,  # 'col_1'을 hover 데이터에 포함시키기
#     'col_2': ':.2f',  # 'col_2'를 hover 데이터에 포함시키고, 소수점 아래 두 자리까지 표시
#     'col_3': ':.2s',  # 'col_3'를 간결한 형식으로 표시 (예: 12345 -> "12.35K", 6789000 -> "6.79M")
#     'col_4': False  # 'col_4'는 hover 데이터에 포함하지 않기
# }
# ```

# %%
import plotly.express as px

# 막대 그래프 생성
fig = px.bar(df1
    , x="Sales"  # x축 데이터
    , y="Month"  # y축 데이터
    , color="Region"  # 막대 색상 구분, 'col_3' 값에 따라 달라짐
    , title="Sales by Month"  # 그래프 제목 설정
    , barmode='group'  # 막대 표시 방식, 'group'은 나란히, 'stack'은 쌓아서 표시
    , hover_data = {
        'Month' : False,
        'Ratio' : ':.2f',
        'Sales' : ':.2s'
    }
)

# X축과 Y축 제목 설정 (선택적)
fig.update_layout(xaxis_title="매출", yaxis_title="월")

# 그래프 화면에 표시
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="e497f29c-8890-4e96-b478-dbe1154914ed" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e497f29c-8890-4e96-b478-dbe1154914ed")) {                    Plotly.newPlot(                        "e497f29c-8890-4e96-b478-dbe1154914ed",                        [{"alignmentgroup":"True","customdata":[[0.234],[0.324],[0.3]],"hovertemplate":"Region=North\u003cbr\u003eSales=%{x:.2s}\u003cbr\u003eRatio=%{customdata[0]:.2f}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"North","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"North","offsetgroup":"North","orientation":"h","showlegend":true,"textposition":"auto","x":[20000,24000,30000],"xaxis":"x","y":["January","February","March"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[0.232],[0.1216],[0.332]],"hovertemplate":"Region=South\u003cbr\u003eSales=%{x:.2s}\u003cbr\u003eRatio=%{customdata[0]:.2f}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"South","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"South","offsetgroup":"South","orientation":"h","showlegend":true,"textposition":"auto","x":[15000,16000,22000],"xaxis":"x","y":["January","February","March"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[0.33],[0.33],[0.27]],"hovertemplate":"Region=East\u003cbr\u003eSales=%{x:.2s}\u003cbr\u003eRatio=%{customdata[0]:.2f}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"East","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"East","offsetgroup":"East","orientation":"h","showlegend":true,"textposition":"auto","x":[180000,26000,27000],"xaxis":"x","y":["January","February","March"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.888888 ...

# %% [markdown]
# # Exercise
# - 일시정지 후 스스로 문제를 풀어보고 강의를 수강해 주세요

# %% [markdown]
# - 아래의 코드를 사용하여 샘플 데이터를 생성
#   - 계산된 결과를 이용하여 월별 및 지역별 매출 합계를 나타내는 막대 그래프를 Plotly Express를 사용하여 시각화하세요.
#     - x축에는 월을, y축에는 매출 합계를 표시하세요
#     - 지역별 구분은 색상으로 나타내세요.
#     - 그래프의 제목을 `"월별 및 지역별 매출 합계"` 로 설정 하세요
#     - 그래프의 barmode를 'group'으로 설정하여 각 지역별 막대가 나란히 표시되도록 하세요.
# - 추가 도전 과제:
#   - Profit_Margin column을 계산하세요.
#     - Profit/Revenue
#     - tootip 에서 Region을 제거하고, Profit_Margin을 소숫점 두째자리 까지 나타내세요.

# %%
import pandas as pd
import numpy as np
import plotly.express as px

# 샘플 데이터 생성
np.random.seed(0)
months = ['January', 'February', 'March', 'April', 'May', 'June',
          'July', 'August', 'September', 'October', 'November', 'December']
regions = ['North', 'South', 'East', 'West']

data = {# 이 코드는 이해하지 못하셔도 됩니다.
    'Month': np.random.choice(months, 100, replace=True),
    'Sales': np.random.randint(200, 1000, 100),
    'Profit': np.random.randint(20, 100, 100),
    'Region': np.random.choice(regions, 100, replace=True)
}

df = pd.DataFrame(data)

# %%
df.head()
# Out:
#       Month  Sales  Profit Region
# 0      June    505      33  South
# 1   January    781      91   East
# 2     April    369      76  South
# 3  December    875      44  South
# 4     April    648      99  South

# %%
import plotly.express as px

# 막대 그래프 생성
fig = px.bar(df
    , x="Month"  # x축 데이터
    , y="Sales"  # y축 데이터
    , color="Region"  # 막대 색상 구분, 'col_3' 값에 따라 달라짐
    , title="월별 및 지역별 매출 합계"  # 그래프 제목 설정
    , barmode='group'  # 막대 표시 방식, 'group'은 나란히, 'stack'은 쌓아서 표시

)

# X축과 Y축 제목 설정 (선택적)
#fig.update_layout(xaxis_title="매출", yaxis_title="")

# 그래프 화면에 표시
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="53420dc5-9c3f-4a1b-aa02-0926a4cac7d0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("53420dc5-9c3f-4a1b-aa02-0926a4cac7d0")) {                    Plotly.newPlot(                        "53420dc5-9c3f-4a1b-aa02-0926a4cac7d0",                        [{"alignmentgroup":"True","hovertemplate":"Region=South\u003cbr\u003eMonth=%{x}\u003cbr\u003eSales=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"South","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"South","offsetgroup":"South","orientation":"v","showlegend":true,"textposition":"auto","x":["June","April","December","April","June","August","July","April","April","January","April","October","November","November","October","December","June","December","July","May","June","January"],"xaxis":"x","y":[505,369,875,648,456,587,810,794,905,978,382,294,426,469,610,982,661,352,310,645,526,487],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=East\u003cbr\u003eMonth=%{x}\u003cbr\u003eSales=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"East","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"East","offsetgroup":"East","orientation":"v","showlegend":true,"textposition":"auto","x":["January","August","September","November","August","September","January","August","March","August","March","May","June","September","March","December","April","May","May","April","May","August"],"xaxis":"x","y":[781,295,754,401,570,583,348,236,475,374,754,644,789,480,460,949,798,349,225,317,795,321],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=North\u003cbr\u003eMonth=%{x}\u003cbr\u003eSales=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"North","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"North","offsetgroup":"North","orientation":"v","showlegend":true,"textposition":"auto","x":["October","March","September","July","August","February","June","May","April","April","February","February","October","January","May","August","December","January","January","June","May","September","February","April","August","January","April","November"],"xaxis":"x","y":[397,890,568,712,755,223,899,774,934,762,982,286,243,970,280,232,328,571,384,688,715,496,528,448,523,339,707,963],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=West\u003cbr\u003eMonth=%{x}\u003cbr\u003eSales=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"West","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"West","offsetgroup":"West","orientation":"v","showlegend":true,"textposition":"auto","x":["April","May","February","October","September","October","January","June","March","September","April","April","October","November","July","May","February","February","August","October","July","October","November","May","May","September","May","June"],"xaxis":"x","y":[806,492,583,330,577,298,323,939,409,611,241,258,211,507,486,837,970,219,807,650,380,821,896,728,664,873,428,669],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.33333333333333 ...

# %%
df.groupby(by = ['Month', 'Region']).size()
# Out:
# Month      Region
# April      East      2
#            North     4
#            South     5
#            West      3
# August     East      5
#            North     3
#            South     1
#            West      1
# December   East      1
#            North     1
#            South     3
# February   North     4
#            West      3
# January    East      2
#            North     4
#            South     2
#            West      1
# July       North     1
#            South     2
#            West      2
# June       East      1
#            North     2
#            South     4
#            West      2
# March      East      3
#            North     1
#            West      1
# May        East      4
#            North     3
#            South     1
#            West      5
# November   East      1
#            North     1
#            South     2
#            West      2
# October    North     2
#            South     2
#            West      5
# September  East      3
#            North     2
#            West      3
# dtype: int64

# %%
df_agg = df.groupby(by = ['Month', 'Region']).Sales.sum().reset_index()
df_agg.groupby(by=['Month', 'Region']).size()
# Out:
# Month      Region
# April      East      1
#            North     1
#            South     1
#            West      1
# August     East      1
#            North     1
#            South     1
#            West      1
# December   East      1
#            North     1
#            South     1
# February   North     1
#            West      1
# January    East      1
#            North     1
#            South     1
#            West      1
# July       North     1
#            South     1
#            West      1
# June       East      1
#            North     1
#            South     1
#            West      1
# March      East      1
#            North     1
#            West      1
# May        East      1
#            North     1
#            South     1
#            West      1
# November   East      1
#            North     1
#            South     1
#            West      1
# October    North     1
#            South     1
#            West      1
# September  East      1
#            North     1
#            West      1
# dtype: int64

# %%
import plotly.express as px

# 막대 그래프 생성
fig = px.bar(df
    , x="Month"  # x축 데이터
    , y="Sales"  # y축 데이터
    , color="Region"  # 막대 색상 구분, 'col_3' 값에 따라 달라짐
    , title="월별 및 지역별 매출 합계"  # 그래프 제목 설정
    , barmode='group'  # 막대 표시 방식, 'group'은 나란히, 'stack'은 쌓아서 표시

)

# X축과 Y축 제목 설정 (선택적)
# fig.update_layout(xaxis_title="x_title_name", yaxis_title="y_title_name")

# 그래프 화면에 표시
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="e7a8c061-c7e8-4f5b-8efe-84d07869127c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e7a8c061-c7e8-4f5b-8efe-84d07869127c")) {                    Plotly.newPlot(                        "e7a8c061-c7e8-4f5b-8efe-84d07869127c",                        [{"alignmentgroup":"True","hovertemplate":"Region=South\u003cbr\u003eMonth=%{x}\u003cbr\u003eSales=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"South","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"South","offsetgroup":"South","orientation":"v","showlegend":true,"textposition":"auto","x":["June","April","December","April","June","August","July","April","April","January","April","October","November","November","October","December","June","December","July","May","June","January"],"xaxis":"x","y":[505,369,875,648,456,587,810,794,905,978,382,294,426,469,610,982,661,352,310,645,526,487],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=East\u003cbr\u003eMonth=%{x}\u003cbr\u003eSales=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"East","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"East","offsetgroup":"East","orientation":"v","showlegend":true,"textposition":"auto","x":["January","August","September","November","August","September","January","August","March","August","March","May","June","September","March","December","April","May","May","April","May","August"],"xaxis":"x","y":[781,295,754,401,570,583,348,236,475,374,754,644,789,480,460,949,798,349,225,317,795,321],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=North\u003cbr\u003eMonth=%{x}\u003cbr\u003eSales=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"North","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"North","offsetgroup":"North","orientation":"v","showlegend":true,"textposition":"auto","x":["October","March","September","July","August","February","June","May","April","April","February","February","October","January","May","August","December","January","January","June","May","September","February","April","August","January","April","November"],"xaxis":"x","y":[397,890,568,712,755,223,899,774,934,762,982,286,243,970,280,232,328,571,384,688,715,496,528,448,523,339,707,963],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=West\u003cbr\u003eMonth=%{x}\u003cbr\u003eSales=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"West","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"West","offsetgroup":"West","orientation":"v","showlegend":true,"textposition":"auto","x":["April","May","February","October","September","October","January","June","March","September","April","April","October","November","July","May","February","February","August","October","July","October","November","May","May","September","May","June"],"xaxis":"x","y":[806,492,583,330,577,298,323,939,409,611,241,258,211,507,486,837,970,219,807,650,380,821,896,728,664,873,428,669],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.33333333333333 ...

# %%
## 추가
df_agg.head()
# Out:
#     Month Region  Sales
# 0   April   East   1115
# 1   April  North   2851
# 2   April  South   3098
# 3   April   West   1305
# 4  August   East   1796

# %%
df.head()
# Out:
#       Month  Sales  Profit Region
# 0      June    505      33  South
# 1   January    781      91   East
# 2     April    369      76  South
# 3  December    875      44  South
# 4     April    648      99  South

# %%
df_agg2 = df.groupby(['Month', 'Region']).agg(
    Sales_sum = ( 'Sales', 'sum'),
    Profit_sum = ( 'Profit', 'sum')
).reset_index()

df_agg2['Profit_ratio'] = df_agg2.Profit_sum / df_agg2.Sales_sum
df_agg2
# Out:
#         Month Region  Sales_sum  Profit_sum  Profit_ratio
# 0       April   East       1115         108      0.096861
# 1       April  North       2851         264      0.092599
# 2       April  South       3098         328      0.105875
# 3       April   West       1305         196      0.150192
# 4      August   East       1796         260      0.144766
# 5      August  North       1510         172      0.113907
# 6      August  South        587          58      0.098807
# 7      August   West        807          81      0.100372
# 8    December   East        949          55      0.057956
# 9    December  North        328          29      0.088415
# 10   December  South       2209         178      0.080579
# 11   February  North       2019         311      0.154037
# 12   February   West       1772         107      0.060384
# 13    January   East       1129         164      0.145261
# 14    January  North       2264         223      0.098498
# 15    January  South       1465          90      0.061433
# 16    January   West        323          22      0.068111
# 17       July  North        712          96      0.134831
# 18       July  South       1120          85      0.075893
# 19       July   West        866         110      0.127021
# 20       June   East        789          54      0.068441
# 21       June  North       1587         116      0.073094
# 22       June  South       2148         223      0.103818
# 23       June   West       1608         112      0.069652
# 24      March   East       1689         182      0.107756
# 25      March  North        890          99      0.111236
# 26      March   West        409          71      0.173594
# 27        May   East       2013         241      0.119722
# 28        May  North       1769         147      0.083098
# 29        May  South        645          95      0.147287
# 30        May   West       3149         174      0.055256
# 31   November   East        401          87      0.216958
# 32   November  North        963          91      0.094496
# 33   November  South        895         143      0.159777
# 34   November   West       1403         103      0.073414
# 35    October  North        640          99      0.154688
# 36    October  South        904         116      0.128319
# 37    October   West       2310         241      0.104329
# 38  September   East       1817         206      0.113374
# 39  September  North       1064         117      0.109962
# 40  September   West       2061         120      0.058224

# %%
import plotly.express as px

# 막대 그래프 생성
fig = px.bar(df_agg2
    , x="Month"  # x축 데이터
    , y="Sales_sum"  # y축 데이터
    , color="Region"  # 막대 색상 구분, 'col_3' 값에 따라 달라짐
    , title="월별 및 지역별 매출 합계"  # 그래프 제목 설정
    , barmode='group'  # 막대 표시 방식, 'group'은 나란히, 'stack'은 쌓아서 표시
    , hover_data = {
        'Profit_ratio' : ':.2f'
    }
)

# X축과 Y축 제목 설정 (선택적)
#fig.update_layout(xaxis_title="매출", yaxis_title="")

# 그래프 화면에 표시
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="3a4e1d48-71c0-4056-9f7e-8fd77f750c5e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3a4e1d48-71c0-4056-9f7e-8fd77f750c5e")) {                    Plotly.newPlot(                        "3a4e1d48-71c0-4056-9f7e-8fd77f750c5e",                        [{"alignmentgroup":"True","customdata":[[0.0968609865470852],[0.1447661469933185],[0.05795574288724974],[0.14526129317980513],[0.06844106463878327],[0.10775606867969213],[0.11972180824639841],[0.2169576059850374],[0.11337369290038525]],"hovertemplate":"Region=East\u003cbr\u003eMonth=%{x}\u003cbr\u003eSales_sum=%{y}\u003cbr\u003eProfit_ratio=%{customdata[0]:.2f}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"East","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"East","offsetgroup":"East","orientation":"v","showlegend":true,"textposition":"auto","x":["April","August","December","January","June","March","May","November","September"],"xaxis":"x","y":[1115,1796,949,1129,789,1689,2013,401,1817],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[0.09259908803928446],[0.11390728476821192],[0.08841463414634146],[0.15403665180782566],[0.09849823321554771],[0.1348314606741573],[0.07309388783868935],[0.11123595505617978],[0.08309779536461277],[0.09449636552440291],[0.1546875],[0.1099624060150376]],"hovertemplate":"Region=North\u003cbr\u003eMonth=%{x}\u003cbr\u003eSales_sum=%{y}\u003cbr\u003eProfit_ratio=%{customdata[0]:.2f}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"North","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"North","offsetgroup":"North","orientation":"v","showlegend":true,"textposition":"auto","x":["April","August","December","February","January","July","June","March","May","November","October","September"],"xaxis":"x","y":[2851,1510,328,2019,2264,712,1587,890,1769,963,640,1064],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[0.10587475790832795],[0.09880749574105621],[0.08057944771389769],[0.06143344709897611],[0.07589285714285714],[0.10381750465549348],[0.14728682170542637],[0.15977653631284916],[0.12831858407079647]],"hovertemplate":"Region=South\u003cbr\u003eMonth=%{x}\u003cbr\u003eSales_sum=%{y}\u003cbr\u003eProfit_ratio=%{customdata[0]:.2f}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"South","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"South","offsetgroup":"South","orientation":"v","showlegend":true,"textposition":"auto","x":["April","August","December","January","July","June","May","November","October"],"xaxis":"x","y":[3098,587,2209,1465,1120,2148,645,895,904],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[0.15019157088122606],[0.10037174721189591],[0.06038374717832957],[0.06811145510835913],[0.12702078521939955],[0.06965174129353234],[0.17359413202933985],[0.05525563671006669],[0.07341411261582323],[0.10432900432900433],[0.05822416302765648]],"hovertemplate":"Region=West\u003cbr\u003eMonth=%{x}\u003cbr\u003eSales_sum=%{y}\u003cbr\u003eProfit_ratio=%{customdata[0]:.2f}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"West","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"West","offsetgroup":"West","orientation":"v","showlegend":true,"textposition":"auto","x":["April","August","February","January","July","June","March","May","November","October","September"],"xaxis":"x","y":[1305,807,1772,323,866,1608,409,3149,1403,2310,2061],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444," ...

# %% [markdown]
# ---
# -  🔒 저작권 및 사용 조건 (중요)
#   - **저작권 보호**: 이 강의 노트는 저작권법에 의해 엄격히 보호됩니다.
#   - **무단 사용 금지**: 어떠한 형태로든 상업적 사용이 엄격히 금지됩니다.
#   - **개인용도 한정**: 이 자료는 교육 목적으로만 사용이 허가되며, 개인적인 학습 외의 목적으로 사용할 수 없습니다.
#   - **위반 시 조치**: 저작권법 위반 시 법적 조치가 취해질 수 있습니다.
# ---
#
# <img src="https://i.ibb.co/1MPXBQZ/ringodata-banner-v2.jpg" width="200"/>
